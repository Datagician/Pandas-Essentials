# %%
import pandas as pd

# %%
# 1- dimensional 
mobiles=pd.Series(['nokia','android','iphone'])
mobiles
# Out:
# 0      nokia
# 1    android
# 2     iphone
# dtype: object

# %%
# 1-dimensional 
bag= pd.Series(['charger', 'mobile', 'airpods'])
bag
# Out:
# 0    charger
# 1     mobile
# 2    airpods
# dtype: object

# %%
# 2- DIMENSIONAL 
junboo=pd.DataFrame({'electronics':mobiles, 'items':bag})
junboo
# Out:
#   electronics    items
# 0       nokia  charger
# 1     android   mobile
# 2      iphone  airpods

# %% [markdown]
# # Importing data

# %%
phone_csv= pd.read_csv("Mobile phone price.csv")

# %%
phone_csv
# Out:
#        Brand              Model Storage    RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# 0          12 + 12 + 12                    3095       999
# ...

# %%
phone_csv.head()
# Out:
#      Brand              Model Storage    RAM  Screen Size (inches)  \
# 0    Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1  Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2  OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3   Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4   Google            Pixel 6   128 GB   8 GB                  6.4
#
#           Camera (MP)  Battery Capacity (mAh) Price ($)
# 0        12 + 12 + 12                    3095       999
# 1  108 + 10 + 10 + 12                    5000      1199
# 2     48 + 50 + 8 + 2                    4500       899
# 3      64 + 8 + 5 + 2                    5020       279
# 4           50 + 12.2                    4614       799

# %% [markdown]
# # export data

# %%
phone_csv.to_csv('modified_phone_csv',index=False)

# %%
modified_phone= pd.read_csv('modified_phone_csv')

# %%
modified_phone
# Out:
#        Brand              Model Storage    RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# 0          12 + 12 + 12                    3095       999
# ...

# %% [markdown]
# # Attribute functions

# %%
modified_phone.dtypes
# Out:
# Brand                     object
# Model                     object
# Storage                   object
# RAM                       object
# Screen Size (inches)      object
# Camera (MP)               object
# Battery Capacity (mAh)     int64
# Price ($)                 object
# dtype: object

# %%
modified_phone.columns
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='object')

# %%
modified_phone.index
# Out:
# RangeIndex(start=0, stop=407, step=1)

# %%
# attribute function
modified_phone.describe
# Out:
# <bound method NDFrame.describe of        Brand              Model Storage    RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# ...

# %%
# function call when we put parentesis after function and it works on integer type
modified_phone.describe()
# Out:
#        Battery Capacity (mAh)
# count              407.000000
# mean              4676.476658
# std                797.193713
# min               1821.000000
# 25%               4300.000000
# 50%               5000.000000
# 75%               5000.000000
# max               7000.000000

# %%
modified_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    object
#  1   Model                   407 non-null    object
#  2   Storage                 407 non-null    object
#  3   RAM                     407 non-null    object
#  4   Screen Size (inches)    407 non-null    object
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 25.6+ KB

# %%
modified_phone.mean()
# Out:
# /var/folders/pq/rgl2qmvs16s3hxptjb9546v00000gn/T/ipykernel_994/2456565111.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   modified_phone.mean()
# Battery Capacity (mAh)    4676.476658
# dtype: float64

# %%
# to view a single column
modified_phone['Battery Capacity (mAh)']
# Out:
# 0      3095
# 1      5000
# 2      4500
# 3      5020
# 4      4614
#        ...
# 402    4300
# 403    4160
# 404    3687
# 405    4025
# 406    4500
# Name: Battery Capacity (mAh), Length: 407, dtype: int64

# %%
modified_phone['Battery Capacity (mAh)'].sum()
# Out:
# 1903326

# %%
modified_phone.tail()
# Out:
#        Brand              Model Storage  RAM  Screen Size (inches)  \
# 402  Samsung   Galaxy Note20 5G      128    8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128    6                 6.57
# 404    Apple  iPhone 12 Pro Max      128    6                  6.7
# 405     Oppo              Reno3      128    8                  6.4
# 406  Samsung    Galaxy S10 Lite      128    6                  6.7
#
#     Camera (MP)  Battery Capacity (mAh) Price ($)
# 402    12+64+12                    4300      1049
# 403    48+8+2+2                    4160       349
# 404    12+12+12                    3687      1099
# 405   48+13+8+2                    4025       429
# 406     48+12+5                    4500       649

# %%
 #to make lower case letters of any column
modified_phone['Brand'].str.lower()
# Out:
# 0        apple
# 1      samsung
# 2      oneplus
# 3       xiaomi
# 4       google
#         ...
# 402    samsung
# 403     xiaomi
# 404      apple
# 405       oppo
# 406    samsung
# Name: Brand, Length: 407, dtype: object

# %% [markdown]
# # index and location

# %%
# .loc picks indexing while .iloc picks location
bird=pd.Series(['pigeon','sparrow', 'crow', 'hen', 'duck'], index=[0,2,3,4,5])

# %%
bird
# Out:
# 0     pigeon
# 2    sparrow
# 3       crow
# 4        hen
# 5       duck
# dtype: object

# %%
bird.loc[4]
# Out:
# 'hen'

# %%
bird.iloc[4]
# Out:
# 'duck'

# %%
modified_phone
# Out:
#        Brand              Model Storage    RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# 0          12 + 12 + 12                    3095       999
# ...

# %%
modified_phone.loc[4] # indexing
# Out:
# Brand                        Google
# Model                       Pixel 6
# Storage                      128 GB
# RAM                            8 GB
# Screen Size (inches)            6.4
# Camera (MP)               50 + 12.2
# Battery Capacity (mAh)         4614
# Price ($)                       799
# Name: 4, dtype: object

# %%
modified_phone.iloc[4] #position
# Out:
# Brand                        Google
# Model                       Pixel 6
# Storage                      128 GB
# RAM                            8 GB
# Screen Size (inches)            6.4
# Camera (MP)               50 + 12.2
# Battery Capacity (mAh)         4614
# Price ($)                       799
# Name: 4, dtype: object

# %%
modified_phone.iloc[:4] # can be done with head fuction as well
# Out:
#      Brand              Model Storage    RAM  Screen Size (inches)  \
# 0    Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1  Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2  OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3   Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
#
#           Camera (MP)  Battery Capacity (mAh) Price ($)
# 0        12 + 12 + 12                    3095       999
# 1  108 + 10 + 10 + 12                    5000      1199
# 2     48 + 50 + 8 + 2                    4500       899
# 3      64 + 8 + 5 + 2                    5020       279

# %%
  modified_phone['Brand']    #can be done with the folowing function as well ...modified_phone.Brand
# Out:
# 0        Apple
# 1      Samsung
# 2      OnePlus
# 3       Xiaomi
# 4       Google
#         ...
# 402    Samsung
# 403     Xiaomi
# 404      Apple
# 405       Oppo
# 406    Samsung
# Name: Brand, Length: 407, dtype: object

# %%
modified_phone[modified_phone['Model']=='iPhone XR'] # To access any feature from within a column
# Out:
#      Brand      Model Storage   RAM  Screen Size (inches) Camera (MP)  \
# 39   Apple  iPhone XR    64 GB  3 GB                  6.1          12
# 68   Apple  iPhone XR    64 GB  3 GB                  6.1     12 + 12
# 308  Apple  iPhone XR       64     3                  6.1        12+7
# 355  Apple  iPhone XR       64     3                  6.1          12
# 396  Apple  iPhone XR      128     3                  6.1       12+12
#
#      Battery Capacity (mAh) Price ($)
# 39                     2942       499
# 68                     2942       499
# 308                    2942       599
# 355                    2942       499
# 396                    2942       599

# %%
modified_phone[modified_phone['Battery Capacity (mAh)']>6000]
# Out:
#        Brand       Model Storage  RAM  Screen Size (inches)  \
# 208  Samsung  Galaxy M62    128GB  8GB                  6.7
# 334  Samsung  Galaxy M51      128    6                  6.7
#
#                  Camera (MP)  Battery Capacity (mAh) Price ($)
# 208  64MP + 12MP + 5MP + 5MP                    7000     $429
# 334                64+12+5+5                    7000       449

# %%
#For comparing two columns.....

pd.crosstab(modified_phone['Screen Size (inches)'],modified_phone['Price ($)'])
# Out:
# Price ($)             $1,199   $1,299   $109   $119   $129   $139   $149   \
# Screen Size (inches)
# 4.5                         0        0      0      0      0      0      0
# 4.7                         0        0      0      0      0      0      0
# 5.4                         0        0      0      0      0      0      0
# 5.5                         0        0      0      0      0      0      0
# 5.7                         0        0      0      0      0      0      0
# 5.9                         0        0      0      0      0      0      0
# 5.99                        0        0      0      0      0      0      0
# 6                           0        0      0      0      0      1      0
# 6.1                         0        1      0      0      0      0      0
# 6.15                        0        0      0      0      0      0      0
# 6.2                         0        0      0      0      0      0      0
# ...

# %%
#for comparing more than two types......it actually compares with integer types
modified_phone.groupby('Brand').mean()
# Out:
#             Battery Capacity (mAh)
# Brand
# Apple                  2863.900000
# Asus                   5000.000000
# Blackberry             3500.000000
# CAT                    4200.000000
# Google                 4019.857143
# Huawei                 4161.666667
# LG                     4100.000000
# Motorola               5021.739130
# Nokia                  4502.857143
# OnePlus                4415.000000
# Oppo                   4631.339286
# Realme                 5176.744186
# Samsung                4936.708861
# Sony                   4500.000000
# Vivo                   4750.000000
# Xiaomi                 5101.791045

# %%
modified_phone['Battery Capacity (mAh)'].plot()
# Out:
# <AxesSubplot:>

# %%
heart=pd.read_csv('heart.csv')

# %%
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
pd.crosstab(heart['sex'],heart['thal'])
# Out:
# thal  0   1    2    3
# sex
# 0     3   4  252   53
# 1     4  60  292  357

# %%
heart.groupby('sex').count()
# Out:
#      age   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# sex
# 0    312  312       312   312  312      312      312    312      312    312
# 1    713  713       713   713  713      713      713    713      713    713
#
#       ca  thal  target
# sex
# 0    312   312     312
# 1    713   713     713

# %%
heart[heart['chol']>=450]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 158   67    0   2       115   564    0        0      160      0      1.6
# 192   67    0   2       115   564    0        0      160      0      1.6
# 464   67    0   2       115   564    0        0      160      0      1.6
#
#      slope  ca  thal  target
# 158      1   0     3       1
# 192      1   0     3       1
# 464      1   0     3       1

# %%
heart['thalach']
# Out:
# 0       168
# 1       155
# 2       125
# 3       161
# 4       106
#        ...
# 1020    164
# 1021    141
# 1022    118
# 1023    159
# 1024    113
# Name: thalach, Length: 1025, dtype: int64

# %%
heart[heart['thalach']==180]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 57    48    1   1       130   245    0        0      180      0      0.2
# 324   48    1   1       130   245    0        0      180      0      0.2
# 541   44    1   2       140   235    0        0      180      0      0.0
# 581   44    1   2       140   235    0        0      180      0      0.0
# 740   44    1   2       140   235    0        0      180      0      0.0
# 752   48    1   1       130   245    0        0      180      0      0.2
#
#      slope  ca  thal  target
# 57       1   0     2       1
# 324      1   0     2       1
# 541      2   0     2       1
# 581      2   0     2       1
# 740      2   0     2       1
# 752      1   0     2       1

# %%
heart.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart['cp'].plot()
# Out:
# <AxesSubplot:>

# %%
heart['chol'].hist()
# Out:
# <AxesSubplot:>

# %%
heart['age'].replace('[\.\]','').astype(int)
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # changing data

# %%
heart['age'].mean()
# Out:
# 54.43414634146342

# %%
# Filling missing values 
# first we take mean value....heart['age'].mean()......after that we do follwing....
# heart['age'].fillna(heart['age'].mean(),inplace=true).......by writing inline=true save data in original file

# %%
# to remove missing values completely from data set
heart.dropna()       #same use inplace=True if we want to make change in origional dataset or...
we can assign a variable to the function

# %% [markdown]
# # Add, remove and change column

# %%
# to add new column or change in existing column
zinda=pd.Series([3,4,5,6,7,8])
heart['survived']=zinda

# %%
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  survived
# ...

# %%
heart.dropna()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
#
#    ca  thal  target  survived
# 0   2     3       0       3.0
# 1   0     3       0       4.0
# 2   0     3       0       5.0
# 3   1     3       0       6.0
# 4   3     2       0       7.0
# 5   0     2       1       8.0

# %%
# making new column from existing columns
heart['product']=heart['thal']*heart['survived']

# %%
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  survived  product
# ...

# %%
heart['data']=True

# %%
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  survived  product  data
# ...

# %%
# to remove column from data
heart.drop('survived',axis=1,inplace=True)

# %%
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  product  data
# ...

# %% [markdown]
# # manipulating data

# %%
# shuffling of data         .sample is used to shuffle data
heart.sample(frac=1)     #frac=1 mean 100% data, frac=0.5 mean 50% data.
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 529   69    1   3       160   234    1        0      131      0      0.1
# 805   53    1   0       142   226    0        0      111      1      0.0
# 781   58    1   0       146   218    0        1      105      0      2.0
# 788   62    0   0       138   294    1        1      106      0      1.9
# 257   64    0   0       180   325    0        1      154      1      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 140   57    1   0       152   274    0        1       88      1      1.2
# 632   45    0   1       130   234    0        0      175      0      0.6
# 736   59    1   0       110   239    0        0      142      1      1.2
# 978   44    1   0       110   197    0        0      177      0      0.0
# 288   58    0   2       120   340    0        1      172      0      0.0
#
#      slope  ca  thal  target  product  data
# 529      1   1     2       1      NaN  True
# ...

# %%
# should move from little data shuffle to bigger  
heart.sample(frac=0.005)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 326   54    1   1       192   283    0        0      195      0      0.0
# 349   62    0   2       130   263    0        1       97      0      1.2
# 455   69    1   3       160   234    1        0      131      0      0.1
# 610   43    0   0       132   341    1        0      136      1      3.0
# 117   43    1   0       120   177    0        0      120      1      2.5
#
#      slope  ca  thal  target  product  data
# 326      2   1     3       0      NaN  True
# 349      1   1     3       0      NaN  True
# 455      1   1     2       1      NaN  True
# 610      1   0     3       0      NaN  True
# 117      1   0     3       0      NaN  True

# %%
# bringing back the origional data form after shuffling
heart.reset_index(drop= True,inplace=True)

# %%
heart
# Out:
#       level_0  index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  \
# 0           0      0   52    1   0       125   212    0        1      168
# 1           1      1   53    1   0       140   203    1        0      155
# 2           2      2   70    1   0       145   174    0        1      125
# 3           3      3   61    1   0       148   203    0        1      161
# 4           4      4   62    0   0       138   294    1        1      106
# ...       ...    ...  ...  ...  ..       ...   ...  ...      ...      ...
# 1020     1020   1020   59    1   1       140   221    0        1      164
# 1021     1021   1021   60    1   0       125   258    0        0      141
# 1022     1022   1022   47    1   0       110   275    0        0      118
# 1023     1023   1023   50    0   0       110   254    0        0      159
# 1024     1024   1024   54    1   0       120   188    0        1      113
#
#       exang  oldpeak  slope  ca  thal  target  product  data
# ...
